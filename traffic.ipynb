# %%
# import psycopg2
import pandas as pd
import sqlalchemy

# %%
username = 'telrich'
password = '28_March_2000'
host = 'telrichserver.postgres.database.azure.com'
database = 'newdb'

conn_str = f'postgresql+psycopg2://{username}:{password}@{host}/{database}'

# %%
engine = sqlalchemy.create_engine(conn_str, pool_pre_ping=True)
con = engine.connect()

# %%
cur = con.engine

# %%
result = cur.execute("Select * from pg_catalog.pg_tables where schemaname != 'pg_catalog' AND schemaname != 'information_schema'")
result.fetchall()
# Out:
# [('public', 'inventory', 'telrich', None, True, False, False, False),
#  ('public', 'busbreakdowndelay', 'telrich', None, False, False, False, False)]

# %%
query = """CREATE TABLE busBreakdownDelay (
    school_year varchar(10) NOT NULL, 
    busbreakdown_id varchar(20) NOT NULL,
    run_type varchar(30),
    bus_no varchar(20),
    route_number varchar(20),
    reason text,
    school_serviced varchar(250),
    occured_on timestamp default NULL,
    created_on timestamp default NULL,
    boro varchar(30),
    bus_company_name varchar(50),
    how_long_delayed varchar(10),
    number_of_students_on_the_bus integer,
    has_contractor_notified_schools varchar(4),
    has_contractor_notified_parents varchar(4),
    have_you_alerted_opt varchar(4),
    informed_on timestamp default NULL,
    incident_number varchar(10),
    last_updated_on timestamp default NULL,
    breakdown_or_running_late varchar(30) NOT NULL,
    school_age_or_prek varchar(30)
)"""

cur.execute("DROP TABLE IF EXISTS busBreakdownDelay")

cur.execute(query)

# %%
query = "SELECT * FROM busBreakdownDelay"
pd.read_sql_query(query, con)
# Out:
# Empty DataFrame
# Columns: [school_year, busbreakdown_id, run_type, bus_no, route_number, reason, school_serviced, occured_on, created_on, boro, bus_company_name, how_long_delayed, number_of_students_on_the_bus, has_contractor_notified_schools, has_contractor_notified_parents, have_you_alerted_opt, informed_on, incident_number, last_updated_on, breakdown_or_running_late, school_age_or_prek]
# Index: []
#
# [0 rows x 21 columns]

# %%
df = pd.read_csv('Bus_Breakdown_and_Delays.csv')
df.head()
# Out:
#   School_Year  Busbreakdown_ID           Run_Type Bus_No Route_Number  \
# 0   2015-2016          1227538  Special Ed AM Run   2621         J711
# 1   2015-2016          1227539  Special Ed AM Run   1260         M351
# 2   2015-2016          1227540           Pre-K/EI    418            3
# 3   2015-2016          1227541  Special Ed AM Run   4522         M271
# 4   2015-2016          1227542  Special Ed AM Run   3124         M373
#
#           Reason Schools_Serviced             Occurred_On  \
# 0  Heavy Traffic            75003  11/05/2015 08:10:00 AM
# 1  Heavy Traffic            06716  11/05/2015 08:10:00 AM
# 2  Heavy Traffic             C445  11/05/2015 08:09:00 AM
# 3  Heavy Traffic            02699  11/05/2015 08:12:00 AM
# 4  Heavy Traffic            02116  11/05/2015 08:13:00 AM
#
#                Created_On        Boro  ... How_Long_Delayed  \
# 0  11/05/2015 08:12:00 AM  New Jersey  ...              NaN
# 1  11/05/2015 08:12:00 AM   Manhattan  ...            20MNS
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.to

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281110 entries, 0 to 281109
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   School_Year                      281110 non-null  object
#  1   Busbreakdown_ID                  281110 non-null  int64
#  2   Run_Type                         281107 non-null  object
#  3   Bus_No                           281101 non-null  object
#  4   Route_Number                     281103 non-null  object
#  5   Reason                           281108 non-null  object
#  6   Schools_Serviced                 281103 non-null  object
#  7   Occurred_On                      281110 non-null  object
#  8   Created_On                       281110 non-null  object
#  9   Boro                             267649 non-null  object
#  10  Bus_Company_Name                 281110 non-null  object
# ...

# %%
csvTuple = tuple(df.itertuples(index=False, name=None))

# %%
# some = csvTuple[:5]
cur.execu

# %%
query = "INSERT INTO busBreakdownDelay values(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
cur.execute(query, csvTuple)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\SQL\Transportation\traffic.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/SQL/Transportation/traffic.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> query = "INSERT INTO busBreakdownDelay values(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
# ----> <a href='vscode-notebook-cell:/d%3A/SQL/Transportation/traffic.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> cur.execute(query, csvTuple)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File c:\Users\okoro\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     399 if not skip_warning:
#     400     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401 return fn(*args, **kwargs)
#
# ...

# %%
query = "SELECT * FROM busBreakdownDelay"
d = pd.read_sql_query(query, con)
d
# Out:
#   school_year busbreakdown_id           run_type bus_no route_number  \
# 0   2015-2016         1227538  Special Ed AM Run   2621         J711
# 1   2015-2016         1227539  Special Ed AM Run   1260         M351
# 2   2015-2016         1227540           Pre-K/EI    418            3
# 3   2015-2016         1227541  Special Ed AM Run   4522         M271
# 4   2015-2016         1227542  Special Ed AM Run   3124         M373
#
#           reason school_serviced          occured_on          created_on  \
# 0  Heavy Traffic           75003 2015-11-05 08:10:00 2015-11-05 08:12:00
# 1  Heavy Traffic           06716 2015-11-05 08:10:00 2015-11-05 08:12:00
# 2  Heavy Traffic            C445 2015-11-05 08:09:00 2015-11-05 08:13:00
# 3  Heavy Traffic           02699 2015-11-05 08:12:00 2015-11-05 08:14:00
# 4  Heavy Traffic           02116 2015-11-05 08:13:00 2015-11-05 08:14:00
#
#          boro  ... how_long_delayed number_of_students_on_the_bus  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   school_year                      5 non-null      object
#  1   busbreakdown_id                  5 non-null      object
#  2   run_type                         5 non-null      object
#  3   bus_no                           5 non-null      object
#  4   route_number                     5 non-null      object
#  5   reason                           5 non-null      object
#  6   school_serviced                  5 non-null      object
#  7   occured_on                       5 non-null      datetime64[ns]
#  8   created_on                       5 non-null      datetime64[ns]
#  9   boro                             5 non-null      object
#  10  bus_company_name                 5 non-null      object
# ...
